# %%
import json
import pandas as pd

with open('SF6FrameData.json', 'r') as file:
    data = json.load(file)
    sf6_df = pd.DataFrame(data)

# %% [markdown]
# # Dataframe Format
# The format of the dataset is a dataframe of 20 columns of each character and the
# rows are, moves and stats. the actual info is in a dictionary in the elements of
# the dataframe

# %%
sf6_df
# Out:
#                                                   A.K.I.  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                   Blanka  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                    Cammy  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                  Chun-Li  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                  Dee Jay  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                  Dhalsim  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                  E.Honda  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10500', 'taunt': '?', 'bestReversa...
#
#                                                    Guile  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                    Jamie  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                       JP  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                     Juri  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                      Ken  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                 Kimberly  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                     Lily  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                     Luke  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                    Manon  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                   Marisa  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10500', 'taunt': '?', 'bestReversa...
#
#                                                   Rashid  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                      Ryu  \
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '10000', 'taunt': '?', 'bestReversa...
#
#                                                  Zangief
# moves  {'normal': {'Stand LP': {'moveName': 'Stand LP...
# stats  {'health': '11000', 'taunt': '?', 'bestReversa...

# %%
chunli_moves = sf6_df['Chun-Li']['moves']['normal']
chunli_moves_df = pd.DataFrame(chunli_moves).T
chunli_moves_df.to_csv('chunli_moves.csv')
