# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

sf6_chunli = pd.read_csv('chunli_moves.csv')
sf6_chunli
# Out:
#                              moveName                    plnCmd  \
# 0                            Stand LP                        LP
# 1                            Stand MP                        MP
# 2                            Stand HP                        HP
# 3                            Stand LK                        LK
# 4                            Stand MK                        MK
# 5                            Stand HK                        HK
# 6                           Crouch LP                      d+LP
# 7                           Crouch MP                      d+MP
# 8                           Crouch HP                      d+HP
# 9                           Crouch LK                      d+LK
# 10                          Crouch MK                      d+MK
# 11                          Crouch HK                      d+HK
# 12                            Jump LP                      u+LP
# 13                            Jump MP                      u+MP
# ...
